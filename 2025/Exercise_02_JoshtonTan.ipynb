# %%
#Exercise 2.1
def unitconverter():
  try:
    quantity = float(input("Input a quantity: "))
    selectmeasurement = input("Select either length, area or volume: ")
    measurements = ["length", "area", "volume"]
    if selectmeasurement in measurements:
      x = 10**(measurements.index(selectmeasurement) + 1)
      units = {"mm": -3, "cm": -2, "m": 0, "km": 3}
      selectbase = input("Select the base unit of measurement (mm, cm, m, km): ")
      if selectbase in units:
        selectconv = input("Select the base unit of measurement to convert to (mm, cm, m, km): ")
        if selectconv in units:
          multiplier = x**(units[selectbase] - units[selectconv])
          convq = quantity*multiplier
        else:
          return("Invalid")
      else:
        return("Invalid")
    else:
      return("Invalid")
    return(f"{quantity} {selectbase}^{measurements.index(selectmeasurement)+1} = {convq} {selectconv}^{measurements.index(selectmeasurement)+1}")
  except:
    return("Invalid")

unitconverter()

# %%
#Exercise 2.2
def arithseq():
    first = float(input("Please input first term in arithmetic sequence: "))
    diff = float(input("Please input common difference: "))
    no = int(input("Please input no. of terms: "))
    num = 1
    terms = [first]
    while num < no:
      nextterm = terms[-1] + diff
      terms.append(nextterm)
      num += 1
    for x in terms:
      print(x)

arithseq()

# %%
#Exercise 2.3
def arithseq():
    first = float(input("Please input first term in arithmetic sequence: "))
    diff = float(input("Please input common difference: "))
    no = int(input("Please input no. of terms: "))
    num = 1
    terms = [first]
    while num < no:
      nextterm = terms[-1] + diff
      terms.append(nextterm)
      num += 1
    print(f"The No. {no} term in the sequence is: {terms[-1]}")
    print(f"The sum of the first {no} terms in the sequence is: {sum(terms)}")

arithseq()

# %%
#Exercise 2.4
terms = [8]
while sum(terms) <= 1700:
  nextterm = terms[-1] + 9
  terms.append(nextterm)
n = 3*(terms.index(terms[-1])+1)
print(f"Least value of n = {n}")
print(terms)

# %%
#Exercise 2.5
initamt = 100
months = 0
while initamt <= 5000:
  initamt += (100 + 10*(months + 1))
  months += 1
print(months)

# %%
#Exercise 2.6
def power():
  m = int(input("Input the number of terms, m: "))
  n = float(input("Input the nth power: "))
  x = 1
  terms = []
  while x <= m:
    terms.append(x**n)
    x += 1
  for y in terms:
    print(y)

power()
# Out:
# 1.0
# 4.658934345873824
# 11.460648305455756
# 21.705669239162756
# 35.621598937262796

# %%
#Exercise 2.7
def secretno():
  import random
  secret = random.randint(1,100)
  while True:
    try:
      guess = int(input("Input a quantity: "))
      if guess == secret:
        print("Congratulations. You guessed correctly.")
        break
      elif guess < secret:
        print("Your number is too low. Try again.")
      elif guess > secret:
        print("Your number is too high. Try again.")
    except:
      print("Invalid")

secretno()

# %%
#Exercise 2.8
def geoseq():
    first = float(input("Please input first term in geometric sequence: "))
    diff = float(input("Please input common ratio: "))
    no = int(input("Please input no. of terms: "))
    num = 1
    terms = [first]
    while num < no:
      nextterm = terms[-1]*diff
      terms.append(nextterm)
      num += 1
    for x in terms:
      print(x)

geoseq()

# %%
#Exercise 2.9
def geoseq2(x):
    first = float(input("Please input first term in geometric sequence: "))
    diff = x
    no = int(input("Please input no. of terms: "))
    num = 1
    terms = [first]
    while num < no:
      nextterm = terms[-1]*diff
      terms.append(nextterm)
      num += 1
    print(f"The No. {no} term in the sequence is: {terms[-1]}")
    print(f"The sum of the first {no} terms in the sequence is: {sum(terms)}")

geoseq2(float(input("Input common ratio: ")))

# %%
#Exercise 2.10
print(geoseq2(2))
print(geoseq2(0.5))
print(geoseq2(-3))
print(geoseq2(-5/6))
print(geoseq2(4.1))
print(geoseq2(0.7))

# %%
#Exercise 2.11
# (a)
totaldist = 0
days = 0
while totaldist <= 200000:
    totaldist += 2000 + 400*(days)
    days += 1
print(days)

# (b)
dist = 0
days = 0
while dist <= 16000:
    dist = 2000*((11/10)**(days))
    days += 1
print(days)

# (c)
totaldistA = 0
totaldistB = 0
days = 0
while totaldistB <= totaldistA:
    totaldistA += 2000 + 400*(days)
    totaldistB += 2000*((11/10)**(days))
    days += 1
print(days)
